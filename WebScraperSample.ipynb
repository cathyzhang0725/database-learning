# %%
from __future__ import print_function
import urllib3
import unicodedata 
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
import time
import csv
warnings.filterwarnings('ignore')

# %%
file =open('webdata.csv', 'w')
f =csv.writer(file,delimiter=',',quotechar='"')
url = 'Https://www.pokemon.com/us/pokedex/pikachu'

# %%
pool = urllib3.PoolManager()
response = pool.request('GET',url)
response.status
# Out:
# 200

# %%
soup=BeautifulSoup(response.data, "lxml")

# %%
soup.find_all('body')
# Out:
# [<body class="us fluid custom-form-elements ">
#  <!-- Google Tag Manager -->
#  <noscript><iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-V9L7" style="display:none;visibility:hidden" width="0"></iframe></noscript>
#  <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#  new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#  j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#  '//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#  })(window,document,'script','gDataLayer','GTM-V9L7');</script>
#  <!-- End Google Tag Manager -->
#  <div id="gus-wrapper">
#  <div class="pokemon-gus-container" data-api="https://www.pokemon.com/api/gus/" data-locale="en" data-site="pcom" data-width="913px"></div>
#  </div>
#  <div class="main-filler"></div>
#  <nav class="main">
#  <div class="blocker"></div>
#  <div class="content-wrapper">
#  <div class="nav-bar">
# ...

# %%
soup.find('')
# Out:
# <html class="no-js " lang="en">
# <head>
# <meta charset="utf-8"/>
# ...

# %%
soup.find('li')
# Out:
# <li class="visible-signed-in">
# <a href="/us/pokemon-trainer-club/login">
# <div class="avatar-icon-wrapper">
# <img alt="View Profile" class="avatar-icon" src="https://assets.pokemon.com/static2/_ui/img/chrome/profile-navigation/profile-nav-signup.png"/>
# </div>
# </a>
# </li>

# %%
from __future__ import print_function
import urllib3
import unicodedata 
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
import time
import csv
warnings.filterwarnings('ignore')

url="http://www.google.com"

# %%
print ("The first method")
http = urllib3.PoolManager()
response=http.request('GET',url)
response.status
# Out:
# The first method
# 200

# %%
soup = BeautifulSoup(response.data)

# %%
cont = response.read()

# %%
print (cont)
# Out:
# b''

# %%
from __future__ import print_function
import urllib3
import unicodedata 
from bs4 import BeautifulSoup, SoupStrainer, Comment
import warnings
import time
import csv
warnings.filterwarnings('ignore')

# %%
file =open('webdata.csv', 'w')
f =csv.writer(file,delimiter=',',quotechar='"')
url = 'https://www.bobbibrowncosmetics.com/products/14377/makeup/face-and-cheek/best-sellers-cheek#'

# %%
pool = urllib3.PoolManager()
response = pool.request('GET',url)
response.status
# Out:
# 200

# %%
soup=BeautifulSoup(response.data, "lxml")

# %%
soup.find_all("product-thumb__image-wrapper",class_="li")
# Out:
# []
